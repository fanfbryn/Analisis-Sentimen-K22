# %% [markdown]
# <a href="https://colab.research.google.com/github/fanfbryn/Analisis-Sentimen-K22/blob/main/Crawling_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import csv
import pandas as pd

# %%
api_key="####################"
api_secret_key="####################"
access_token="####################"
access_token_secret="####################"

# %%
auth=tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)
search_key="kurikulum 2022"

csvFile=open(search_key+".csv","a+",newline="",encoding="utf-8")
csvWriter=csv.writer(csvFile)

c=[]
i=[]
u=[]
t=[]

for tweet in tweepy.Cursor(api.search,q=search_key,count=1000,lang="id",since="2021-12-21",until="2021-12-24").items():
  print(tweet.created_at, tweet.id, tweet.user.name, tweet.text)
  c.append(tweet.created_at)
  i.append(tweet.id)
  u.append(tweet.user.name)
  t.append(tweet.text.encode("utf-8"))
  tweets=[tweet.created_at,tweet.id, tweet.user.name, tweet.text.encode("utf-8")]
  csvWriter.writerow(tweets)
# Out:
# 2021-12-23 23:58:33 1474167577655930882 cas-e ):) 🦥 RT @schfess: sch! SALAM DARI AKU YG UDAH PAKE KURIKULUM TAUN DEPAN HEHEHEHEHEHEHE INI AKU MAU PILIH MAPEL, EH BTW SEKOLAH PENGGERAK SM KURI…
# 2021-12-23 23:47:09 1474164705996337152 🍪🥛 RT @schfess: sch! SALAM DARI AKU YG UDAH PAKE KURIKULUM TAUN DEPAN HEHEHEHEHEHEHE INI AKU MAU PILIH MAPEL, EH BTW SEKOLAH PENGGERAK SM KURI…
# 2021-12-23 23:45:17 1474164237408694279 Shiif 🔥 RT @schfess: sch! SALAM DARI AKU YG UDAH PAKE KURIKULUM TAUN DEPAN HEHEHEHEHEHEHE INI AKU MAU PILIH MAPEL, EH BTW SEKOLAH PENGGERAK SM KURI…
# 2021-12-23 23:32:13 1474160949137342466 masuk Oxford RT @schfess: sch! SALAM DARI AKU YG UDAH PAKE KURIKULUM TAUN DEPAN HEHEHEHEHEHEHE INI AKU MAU PILIH MAPEL, EH BTW SEKOLAH PENGGERAK SM KURI…
# 2021-12-23 23:31:31 1474160773999980545 Ida Bagus Gede Kresna RT @schfess: sch! SALAM DARI AKU YG UDAH PAKE KURIKULUM TAUN DEPAN HEHEHEHEHEHEHE INI AKU MAU PILIH MAPEL, EH BTW SEKOLAH PENGGERAK SM KURI…
# ...

# %%
dictTweets={"waktu":c, "id":i, "username":u, "text":t}
df=pd.DataFrame(dictTweets, columns=["waktu", "id", "username", "text"])
df
# Out:
#                    waktu  ...                                               text
# 0    2021-12-23 23:58:33  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 1    2021-12-23 23:47:09  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 2    2021-12-23 23:45:17  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 3    2021-12-23 23:32:13  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 4    2021-12-23 23:31:31  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# ...                  ...  ...                                                ...
# 999  2021-12-21 01:31:58  ...  b'RT @cewekbangetid: Enggak cuma buat SMA, kur...
# 1000 2021-12-21 01:31:04  ...  b'RT @cewekbangetid: Kurikulum di tahun 2022 b...
# 1001 2021-12-21 01:30:34  ...  b'RT @cewekbangetid: Rencananya, kurikulum tah...
# 1002 2021-12-21 01:22:05  ...  b'Ramai soal Kurikulum 2022 SMA Tidak Ada Juru...
# 1003 2021-12-21 01:01:54  ...         b'@haechanbakpau 2022 kan ganti kurikulum'
#
# ...

# %%
df=df.reset_index()

# %%
df
# Out:
#       index  ...                                               text
# 0         0  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 1         1  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 2         2  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 3         3  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# 4         4  ...  b'RT @schfess: sch! SALAM DARI AKU YG UDAH PAK...
# ...     ...  ...                                                ...
# 999     999  ...  b'RT @cewekbangetid: Enggak cuma buat SMA, kur...
# 1000   1000  ...  b'RT @cewekbangetid: Kurikulum di tahun 2022 b...
# 1001   1001  ...  b'RT @cewekbangetid: Rencananya, kurikulum tah...
# 1002   1002  ...  b'Ramai soal Kurikulum 2022 SMA Tidak Ada Juru...
# 1003   1003  ...         b'@haechanbakpau 2022 kan ganti kurikulum'
#
# [1004 rows x 5 columns]

# %%
from google.colab import drive
drive.mount('/drive')
df.to_csv('/drive/My Drive/Colab Notebooks/kurikulum2022.csv')
# Out:
# Mounted at /drive
